# %%
# Derek Nissen
# 5/7/2023
# %matplotlib inline
import json
import matplotlib.pyplot as plt
from pullData import *

# %%
# Enter variables
runner = "derek nissen" # First Last
event = "5000 Meter Run"

# %%
# Import data
results = getRunnerData(runner, newData = False)
# Out:
# new data is false
# nissen, derek
# found results
# {'800 Meter Run': [['2:02.26', '4th', 'Finals', 'Suburban GOLD Conference JV/Varsity Championships', 'May 05, 2023'], ['1:59.95', '4th', 'Finals', 'Gardner-Edgerton Trailblazer Invitational', 'Apr 28, 2023'], ['2:02.42', '6th', 'Finals', 'Marc Cleveland Grain Valley Invitational', 'Apr 20, 2023'], ['2:05.45', '1st', 'Finals', 'Jerry Crews Invitational', 'Apr 07, 2023'], ['2:01.73', '2nd', 'Finals', 'Bob Thorpe Invitational', 'Mar 27, 2023'], ['1:59.59', '5th', 'Finals', 'MSHSAA Class 5 Sectional 4', 'May 21, 2022'], ['2:00.55', '3rd', 'Finals', 'Class 5 District 7', 'May 14, 2022'], ['1:59.97', '6th', 'Finals', 'Kansas City Suburban Gold Varsity Conference Championships', 'May 06, 2022'], ['2:04.11', '5th', 'Finals', 'Gardner-Edgerton Trailblazer Invitational', 'Apr 29, 2022'], ['1:59.23', '3rd', 'Finals', 'Grain Valley Invitational', 'Apr 21, 2022'], ['1:59.83', '5th', 'Finals', "33rd Annual Jock's Nitch/PSU Gorilla Relays", 'Apr 08, 2022'], ['2:03.11', '4th', 'Finals', 'Emporia State HS Relays', 'Apr 01, 2022'], ['2:06.20', '1st', 'Finals', 'Bob Thorpe Invitational', 'Mar 25, 2022']], '1600 Meter Run': [['4:27.52', '4th', 'Finals', 'Suburban GOLD Conference JV/Varsity Championships', 'May 05, 2023'], ['4:30.50', '3rd', 'Finals', 'Marc Cleveland Grain Valley Invitational', 'Apr 20, 2023'], ['4:35.10', '6th', 'Finals', 'ESU High School Relays', 'Mar 31, 2023'], ['4:38.55', '1st', 'Finals', 'Bob Thorpe Invitational', 'Mar 27, 2023'], ['4:27.76', '8th', 'Finals', 'Kansas City Suburban Gold Varsity Conference Championships', 'May 06, 2022'], ['4:34.78', '6th', 'Finals', 'Kansas City Relays', 'Apr 15, 2022'], ['4:38.38', '3rd', 'Finals', 'Emporia State HS Relays', 'Apr 01, 2022'], ['4:43.39', '2nd', 'Finals', 'Bob Thorpe Invitational', 'Mar 25, 2022']], 'Three Mile Run': [['20:00.00', '121st', 'Finals', 'MO Roster Import (Internal)', 'Feb 28, 2023']], '5000 Meter Run': [['16:20.00', '29th', 'Finals', 'MSHSAA Class 5 State XC Championships', 'Nov 04, 2022'], ['16:03.89', '9th', 'Finals', 'MSHSAA Class 5 - District 2', 'Oct 29, 2022'], ['16:08.08', '12th', 'Finals', 'KC Suburban Gold/Silver Conference XC', 'Oct 15, 2022'], ['16:29.50', '3rd', 'Finals', 'Haskell Invite', 'Oct 08, 2022'], ['16:35.00', '3rd', 'Finals', 'Sock it to Cancer Grain Valley Invitational', 'Oct 01, 2022'], ['16:35.20', '42nd', 'Finals', 'Gans Creek Classic', 'Sep 24, 2022'], ['16:17.83', '29th', 'Finals', 'Missouri Southern Stampede', 'Sep 17, 2022'], ['16:56.30', '6th', 'Finals', 'Raymore-Peculiar XC Invitational', 'Sep 10, 2022'], ['16:39.70', '23rd', 'Finals', 'Tim Nixon Invitational', 'Sep 03, 2022'], ['16:14.80', '40th', 'Finals', 'MSHSAA Class 5 State XC Championships', 'Nov 05, 2021'], ['16:49.51', '8th', 'Finals', 'MSHSAA Class 5 - District 2', 'Oct 30, 2021'], ['17:04.24', '23rd', 'Finals', 'KC Suburban Gold Conference XC', 'Oct 16, 2021'], ['17:47.30', '5th', 'Finals', 'Butler Bear XC Invitational', 'Oct 09, 2021'], ['17:32.20', '77th', 'Finals', 'KC XC Classic', 'Oct 02, 2021'], ['17:05.80', '116th', 'Finals', 'Gans Creek Classic', 'Sep 25, 2021'], ['17:30.75', '17th', 'Finals', 'Trinity / Valkyrie Invitational', 'Sep 17-18, 2021'], ['18:34.80', '56th', 'Finals', 'Raymore-Peculiar XC Invitational', 'Sep 11, 2021'], ['18:18.35', '42nd', 'Finals', 'MSHSAA Class 5 - District 7', 'Oct 31, 2020'], ['18:11.90', '10th', 'Finals', 'KC Suburban Gold Conference Championships', 'Oct 17, 2020'], ['17:43.70', '122nd', 'Finals', 'KC XC Classic', 'Oct 03, 2020'], ['17:44.80', '78th', 'Finals', 'Gans Creek Classic', 'Sep 26, 2020'], ['18:22.20', '98th', 'Finals', 'Raymore-Peculiar XC Invitational', 'Sep 12, 2020'], ['19:32.50', '115th', 'Finals', 'Foot Locker Midwest Regional', 'Nov 30, 2019'], ['18:47.90', '18th', 'Finals', 'KC Suburban Gold Conference', 'Oct 12, 2019'], ['18:51.20', '5th', 'Finals', 'KC XC Classic', 'Oct 05, 2019'], ['19:27.10', '72nd', 'Finals', 'Gans Creek Classic/Pre-State', 'Sep 27-28, 2019'], ['19:31.10', '38th', 'Finals', 'Raymore-Peculiar  ...

# %%
# Transport data
eventData = results[event]
xValues = [] # Date
yValues = [] # Time
for performance in eventData:
    # Convert date to number
    
    xValues.append(performance[4])

    # Convert time to number value
    sections = performance[0].split(":")
    seconds = 0
    seconds += float(sections[0]) * 60
    if len(sections) >= 2:
        seconds += float(sections[1])
    if len(sections) >= 3: 
        seconds += float(sections[2]) * .1
    yValues.append(seconds)

xValues.reverse()
yValues.reverse()

# %%
# Visualize the data
plt.plot(xValues, yValues)
plt.xticks(rotation='vertical')
plt.show()
